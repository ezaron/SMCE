# %%
include("test.jl")
# Out:
# HAmod did not find HA data files here: ./
# HAmod is using a minimal set of Doodson numbers defined inline.
# Trying to process infile = /home/jovyan/DEMO_FILES/SWOT_L2_LR_SSH_Expert_001_001_20140412T120000_20140412T125126_DG10_01.nc
# First measurement time = 2014-04-12 12:00:00.00
# Last measurement time = 2014-04-12 12:51:26.42
# Scene (600px, 300px):
#   0 Plots
#   1 Child Scene:
#     └ Scene (600px, 300px)
# Saving graphics at SWOT_L2_LR_SSH_Expert_001_001_20140412T120000_20140412T125126_DG10_01.pdf
# nodal modulation is turned OFF (less accurate, but better agreement with checkval)
# Working on cid = M2
# Working on cid = S2
# Working on cid = K1
# Working on cid = O1
# DONE!
# Writing results to file.
# MAXIMUM error compared to checkval [mm] = 0.07022796037940096
# This should be less than 0.1 mm when nodal modulation is turned off.
# It could be more than a 1 mm when the nodal modulation is turned on.
# ...

# %%
ARGS
# Out:
# 1-element Vector{String}:
#  "/home/jovyan/.local/share/jupyt" ⋯ 28 bytes ⋯ "ab5-44bf-a44f-3ddff6475bca.json"
